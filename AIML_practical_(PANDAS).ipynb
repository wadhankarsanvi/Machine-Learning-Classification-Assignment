# %% [markdown]
# <a href="https://colab.research.google.com/github/wadhankarsanvi/Machine-Learning-codes-/blob/main/AIML_practical_(PANDAS).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                                       Panda
# Pandas is having better working algorithms than numpy
#
# Pandas is flexible and through pandas we can work with big data
#
# it is an open source library linke numpy

# %% [markdown]
# importing files or dataset in the colab sheet

# %%
from google.colab import files
uploaded = files.upload()#imported or uploaded the datatset file in the google colab sheet
# Out:
#      <input type="file" id="files-639aa6d2-81a5-4e26-b64a-b763f4f0fab4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-639aa6d2-81a5-4e26-b64a-b763f4f0fab4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('pokemon_data.csv')#dataframes are data stored in rows and columns
df
#we are reading the file in this code
# Out:
#          id                      name  base_experience  height  weight  \
# 0         1                 bulbasaur               64       7      69
# 1         2                   ivysaur              142      10     130
# 2         3                  venusaur              236      20    1000
# 3         4                charmander               62       6      85
# 4         5                charmeleon              142      11     190
# ...     ...                       ...              ...     ...     ...
# 1297  10273   ogerpon-wellspring-mask              275      12     398
# 1298  10274  ogerpon-hearthflame-mask              275      12     398
# 1299  10275  ogerpon-cornerstone-mask              275      12     398
# 1300  10276        terapagos-terastal               90       3     160
# 1301  10277         terapagos-stellar               90      17     770
#
#               types              abilities  \
# 0     grass, poison  overgrow, chlorophyll
# ...

# %% [markdown]
# uploading a excel sheet in the colab

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-0c0854b0-9a00-427c-8676-0623b495bcc0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c0854b0-9a00-427c-8676-0623b495bcc0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# if there is xl file instaed of csv file we can access that too
df_xlsx = pd.read_excel('student.xlsx')
df_xlsx
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4   Unnamed: 5
# 0    Sr. no.       Name        PRN    SECTION       CGPA  scholarship
# 1          1      Sanvi        191          C        9.2          yes
# 2          2     Aaryan        162          C         10           no
# 3          3   Shivangi        164          A        8.1           no
# 4          4     Jayesh        101          D          8          yes
# 5          5   Sharvari        207          D        8.5          yes
# 6          6     Shreya        196          A        8.3           no
# 7          7    Abhinav        301          A         10           no

# %% [markdown]
# sorting and describing data

# %%
print(df.describe())
#this provides all the statistics like mean , std deviation of all the numeric data
# Out:
#                  id  base_experience       height        weight
# count   1302.000000      1302.000000  1302.000000   1302.000000
# mean    2560.927803       161.943932    20.467742    980.863287
# std     3949.887748        82.532554    54.180316   1972.645170
# min        1.000000        36.000000     1.000000      0.000000
# 25%      326.250000        71.000000     5.000000     89.250000
# 50%      651.500000       165.000000    10.000000    315.500000
# 75%      976.750000       222.500000    16.000000    818.000000
# max    10277.000000       608.000000  1000.000000  10000.000000

# %% [markdown]
# Reading Data in Pandas

# %%
print(df.columns)
#reading headers
# Out:
# Index(['id', 'name', 'base_experience', 'height', 'weight', 'types',
#        'abilities', 'moves', 'stats'],
#       dtype='object')

# %%
print(df.head)
#print rows
# Out:
# <bound method NDFrame.head of          id                      name  base_experience  height  weight  \
# 0         1                 bulbasaur               64       7      69
# 1         2                   ivysaur              142      10     130
# 2         3                  venusaur              236      20    1000
# 3         4                charmander               62       6      85
# 4         5                charmeleon              142      11     190
# ...     ...                       ...              ...     ...     ...
# 1297  10273   ogerpon-wellspring-mask              275      12     398
# 1298  10274  ogerpon-hearthflame-mask              275      12     398
# 1299  10275  ogerpon-cornerstone-mask              275      12     398
# 1300  10276        terapagos-terastal               90       3     160
# 1301  10277         terapagos-stellar               90      17     770
#
#               types              abilities  \
# ...

# %%
print(df.head(3))
#first three rows , by default it is first 5 rows
# Out:
#    id       name  base_experience  height  weight          types  \
# 0   1  bulbasaur               64       7      69  grass, poison
# 1   2    ivysaur              142      10     130  grass, poison
# 2   3   venusaur              236      20    1000  grass, poison
#
#                abilities                                           moves  \
# 0  overgrow, chlorophyll  razor-wind, swords-dance, cut, bind, vine-whip
# 1  overgrow, chlorophyll    swords-dance, cut, bind, vine-whip, headbutt
# 2  overgrow, chlorophyll    swords-dance, cut, bind, vine-whip, headbutt
#
#                                                stats
# 0  hp=45, attack=49, defense=49, special-attack=6...
# 1  hp=60, attack=62, defense=63, special-attack=8...
# 2  hp=80, attack=82, defense=83, special-attack=1...

# %% [markdown]
# prints just the name coulmn in the dataset

# %%
print(df['name'])
# Out:
# 0                      bulbasaur
# 1                        ivysaur
# 2                       venusaur
# 3                     charmander
# 4                     charmeleon
#                   ...
# 1297     ogerpon-wellspring-mask
# 1298    ogerpon-hearthflame-mask
# 1299    ogerpon-cornerstone-mask
# 1300          terapagos-terastal
# 1301           terapagos-stellar
# Name: name, Length: 1302, dtype: object

# %% [markdown]
# gives first 10 elements of the provided column name

# %%
print(df['name'][0:10])#doing slicing using only first 10 names
# Out:
# 0     bulbasaur
# 1       ivysaur
# 2      venusaur
# 3    charmander
# 4    charmeleon
# 5     charizard
# 6      squirtle
# 7     wartortle
# 8     blastoise
# 9      caterpie
# Name: name, dtype: object

# %%
df.name
#gives name of the columns
# Out:
# 0                      bulbasaur
# 1                        ivysaur
# 2                       venusaur
# 3                     charmander
# 4                     charmeleon
#                   ...
# 1297     ogerpon-wellspring-mask
# 1298    ogerpon-hearthflame-mask
# 1299    ogerpon-cornerstone-mask
# 1300          terapagos-terastal
# 1301           terapagos-stellar
# Name: name, Length: 1302, dtype: object

# %% [markdown]
# prints the given columns

# %%
print(df[['name','types', 'moves']])
# Out:
#                           name          types  \
# 0                    bulbasaur  grass, poison
# 1                      ivysaur  grass, poison
# 2                     venusaur  grass, poison
# 3                   charmander           fire
# 4                   charmeleon           fire
# ...                        ...            ...
# 1297   ogerpon-wellspring-mask   grass, water
# 1298  ogerpon-hearthflame-mask    grass, fire
# 1299  ogerpon-cornerstone-mask    grass, rock
# 1300        terapagos-terastal         normal
# 1301         terapagos-stellar         normal
#
#                                                   moves
# 0        razor-wind, swords-dance, cut, bind, vine-whip
# 1          swords-dance, cut, bind, vine-whip, headbutt
# 2          swords-dance, cut, bind, vine-whip, headbutt
# 3     mega-punch, fire-punch, thunder-punch, scratch...
# 4     mega-punch, fire-punch, thunder-punch, scratch...
# ...                                                 ...
# ...

# %% [markdown]
# gives specific location

# %%
#integer location based gives whichever value we provide either row or any specific value in the dataset
print(df.iloc[1])
# Out:
# id                                                                 2
# name                                                         ivysaur
# base_experience                                                  142
# height                                                            10
# weight                                                           130
# types                                                  grass, poison
# abilities                                      overgrow, chlorophyll
# moves                   swords-dance, cut, bind, vine-whip, headbutt
# stats              hp=60, attack=62, defense=63, special-attack=8...
# Name: 1, dtype: object

# %% [markdown]
# element from the dataset having 3rd row and 2nd column as its location is printed

# %%
# 3rd row and second column se specific value milegi
print(df.iloc[2,1])
# Out:
# venusaur

# %%
print(df.iloc[3,1])#integere location based function
# Out:
# charmander

# %% [markdown]
# gives the number of rows and columns of the dataset

# %%
print(df.shape)#to find the shape of framework or tells number of rows and columns
# Out:
# (1302, 9)

# %%
df.info()#gives info of the df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1302 non-null   int64
#  1   name             1302 non-null   object
#  2   base_experience  1302 non-null   int64
#  3   height           1302 non-null   int64
#  4   weight           1302 non-null   int64
#  5   types            1302 non-null   object
#  6   abilities        1302 non-null   object
#  7   moves            1268 non-null   object
#  8   stats            1302 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 91.7+ KB

# %% [markdown]
# describe - calculates statistical values like mean max, count etc

# %%
print(df.describe())
#calculate man standarad deviation and mean and statistics of all the numric values
# Out:
#                  id  base_experience       height        weight
# count   1302.000000      1302.000000  1302.000000   1302.000000
# mean    2560.927803       161.943932    20.467742    980.863287
# std     3949.887748        82.532554    54.180316   1972.645170
# min        1.000000        36.000000     1.000000      0.000000
# 25%      326.250000        71.000000     5.000000     89.250000
# 50%      651.500000       165.000000    10.000000    315.500000
# 75%      976.750000       222.500000    16.000000    818.000000
# max    10277.000000       608.000000  1000.000000  10000.000000

# %% [markdown]
# sorts the dataset in ascending or desceding order by the given column name

# %%
df.sort_values('name')
# Out:
#          id                        name  base_experience  height  weight  \
# 459     460                   abomasnow              173      22    1355
# 1084  10060              abomasnow-mega              208      27    1850
# 62       63                        abra               62       9     195
# 358     359                       absol              163      12     470
# 1081  10057                  absol-mega              198      12     490
# ...     ...                         ...              ...     ...     ...
# 1205  10181                  zygarde-10              243      12     335
# 1142  10118  zygarde-10-power-construct              243      12     335
# 717     718                  zygarde-50              270      50    3050
# 1143  10119  zygarde-50-power-construct              300      50    3050
# 1144  10120            zygarde-complete              354      45    6100
#
#                types                              abilities  \
# ...

# %% [markdown]
# sorts the values of column name in descending order

# %%
df.sort_values('name', ascending = False)
# Out:
#          id                        name  base_experience  height  weight  \
# 1144  10120            zygarde-complete              354      45    6100
# 1143  10119  zygarde-50-power-construct              300      50    3050
# 717     718                  zygarde-50              270      50    3050
# 1142  10118  zygarde-10-power-construct              243      12     335
# 1205  10181                  zygarde-10              243      12     335
# ...     ...                         ...              ...     ...     ...
# 1081  10057                  absol-mega              198      12     490
# 358     359                       absol              163      12     470
# 62       63                        abra               62       9     195
# 1084  10060              abomasnow-mega              208      27    1850
# 459     460                   abomasnow              173      22    1355
#
#                types                              abilities  \
# ...

# %%
print(df.sort_values(['height', 'weight'], ascending = False))
# Out:
#          id                 name  base_experience  height  weight  \
# 1214  10190  eternatus-eternamax              563    1000       0
# 1244  10220     centiskorch-gmax              184     750   10000
# 1249  10225       duraludon-gmax              187     430   10000
# 1239  10215       coalossal-gmax              255     420   10000
# 1235  10211        inteleon-gmax              265     400   10000
# ...     ...                  ...              ...     ...     ...
# 594     595               joltik               64       1       6
# 763     764               comfey              170       1       3
# 741     742             cutiefly               61       1       2
# 853     854       sinistea-phony               62       1       2
# 668     669          flabebe-red               61       1       1
#
#                types                              abilities  \
# 1214  poison, dragon                               pressure
# ...

# %% [markdown]
# sorting name coulmn in ascending order and abilities in descending order

# %%
print(df.sort_values(['name', 'abilities'], ascending = [1,0]))#name in ascending and abilities in descending
# Out:
#          id                        name  base_experience  height  weight  \
# 459     460                   abomasnow              173      22    1355
# 1084  10060              abomasnow-mega              208      27    1850
# 62       63                        abra               62       9     195
# 358     359                       absol              163      12     470
# 1081  10057                  absol-mega              198      12     490
# ...     ...                         ...              ...     ...     ...
# 1205  10181                  zygarde-10              243      12     335
# 1142  10118  zygarde-10-power-construct              243      12     335
# 717     718                  zygarde-50              270      50    3050
# 1143  10119  zygarde-50-power-construct              300      50    3050
# 1144  10120            zygarde-complete              354      45    6100
#
#                types                              abilities  \
# ...
